# %% [markdown]
# <a href="https://colab.research.google.com/github/Xander50/C-129/blob/main/C_129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-NASA-Exoplanet-Scraped-Data
# Out:
# Cloning into 'PRO-NASA-Exoplanet-Scraped-Data'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 23 (delta 8), reused 15 (delta 3), pack-reused 0
# Unpacking objects: 100% (23/23), 1.73 MiB | 2.76 MiB/s, done.

# %%
import pandas as pd
planet_df_1=pd.read_csv('/content/PRO-NASA-Exoplanet-Scraped-Data/updated_scraped_data.csv')
new_planet_df_1=pd.read_csv('/content/PRO-NASA-Exoplanet-Scraped-Data/new_scraped_data.csv')

# %%
planet_df_1.head()
# Out:
#    id                  name  light_years_from_earth     planet_mass  \
# 0   0  11 Comae Berenices b                   304.0   19.4 Jupiters
# 1   1    11 Ursae Minoris b                   409.0  14.74 Jupiters
# 2   2       14 Andromedae b                   246.0    4.8 Jupiters
# 3   3         14 Herculis b                    58.0   4.66 Jupiters
# 4   4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar_magnitude  discovery_date  \
# 0            4.72307            2007
# 1            5.01300            2009
# 2            5.23133            2008
# 3            6.61935            2002
# 4            6.21500            1996
#
#                                            hyperlink
# 0  https://exoplanets.nasa.gov/exoplanet-catalog/...
# 1  https://exoplanets.nasa.gov/exoplanet-catalog/...
# 2  https://exoplanets.nasa.gov/exoplanet-catalog/...
# 3  https://exoplanets.nasa.gov/exoplanet-catalog/...
# 4  https://exoplanets.nasa.gov/exoplanet-catalog/...

# %%
new_planet_df_1.head(10)
# Out:
#    id planet_type  discovery_date            mass    planet_radius  \
# 0   0   Gas Giant            2007   19.4 Jupiters   1.08 x Jupiter
# 1   1   Gas Giant            2009  14.74 Jupiters   1.09 x Jupiter
# 2   2   Gas Giant            2008    4.8 Jupiters   1.15 x Jupiter
# 3   3   Gas Giant            2002   4.66 Jupiters   1.15 x Jupiter
# 4   4   Gas Giant            1996   1.78 Jupiters    1.2 x Jupiter
# 5   5   Gas Giant            2020   4.32 Jupiters   1.15 x Jupiter
# 6   6   Gas Giant            2008   10.3 Jupiters   1.11 x Jupiter
# 7   7   Gas Giant            2008      8 Jupiters  1.664 x Jupiter
# 8   8   Gas Giant            2018   0.91 Jupiters   1.24 x Jupiter
# 9   9   Gas Giant            2010   1.99 Jupiters   1.19 x Jupiter
#
#   orbital_radius orbital_period eccentricity detection_method
# 0        1.29 AU       326 days         0.23              NaN
# 1        1.53 AU      1.4 years         0.08              NaN
# ...

# %%
#new_planet_df_1.drop(columns=['discovery_date','mass','detection_method'],inplace=True)
new_planet_df_1.head()
# Out:
#    id planet_type   planet_radius orbital_radius orbital_period eccentricity
# 0   0   Gas Giant  1.08 x Jupiter        1.29 AU       326 days         0.23
# 1   1   Gas Giant  1.09 x Jupiter        1.53 AU      1.4 years         0.08
# 2   2   Gas Giant  1.15 x Jupiter        0.83 AU     185.8 days          0.0
# 3   3   Gas Giant  1.15 x Jupiter        2.93 AU      4.9 years         0.37
# 4   4   Gas Giant   1.2 x Jupiter        1.66 AU      2.2 years         0.68

# %%
headers=["name","light_from_earth","planet_mass","stellar_magnitude","discovery_date","hyperlink","planet_type","mass","planet_radius","orbital_radius","orbital_period","eccentricity","detection_method"]
final_planet_df=pd.DataFrame(columns=headers)
final_planet_df=pd.merge(planet_df_1,new_planet_df_1)
final_planet_df.head()
# Out:
#    id                  name  light_years_from_earth     planet_mass  \
# 0   0  11 Comae Berenices b                   304.0   19.4 Jupiters
# 1   1    11 Ursae Minoris b                   409.0  14.74 Jupiters
# 2   2       14 Andromedae b                   246.0    4.8 Jupiters
# 3   3         14 Herculis b                    58.0   4.66 Jupiters
# 4   4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar_magnitude  discovery_date  \
# 0            4.72307            2007
# 1            5.01300            2009
# 2            5.23133            2008
# 3            6.61935            2002
# 4            6.21500            1996
#
#                                            hyperlink planet_type  \
# 0  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# 1  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# 2  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# ...

# %%
final_planet_df.shape
# Out:
# (5009, 12)

# %%
final_planet_df.to_csv("final_scraped_data.csv")

# %%
a_planet_df=pd.read_csv('/content/PRO-NASA-Exoplanet-Scraped-Data/PSCompPars.csv')
a_planet_df.head()
# Out:
#    id     pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0   0    11 Com b    11 Com        2        1  Radial Velocity       2007
# 1   1    11 UMi b    11 UMi        1        1  Radial Velocity       2009
# 2   2    14 And b    14 And        1        1  Radial Velocity       2008
# 3   3    14 Her b    14 Her        1        2  Radial Velocity       2002
# 4   4  16 Cyg B b  16 Cyg B        3        1  Radial Velocity       1996
#
#                             disc_facility  pl_controv_flag   pl_orbper  ...  \
# 0                        Xinglong Station                0   326.03000  ...
# 1  Thueringer Landessternwarte Tautenburg                0   516.21997  ...
# 2       Okayama Astrophysical Observatory                0   185.84000  ...
# 3                  W. M. Keck Observatory                0  1773.40002  ...
# 4                  Multiple Observatories                0   798.50000  ...
#
# ...

# %%
final_planet_df.shape
# Out:
# (5009, 12)

# %%
a_planet_df.shape
# Out:
# (5009, 85)

# %%
a_planet_df["pl_name"]=a_planet_df["pl_name"].str.lower()
a_planet_df.head()
# Out:
#    id     pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0   0    11 com b    11 Com        2        1  Radial Velocity       2007
# 1   1    11 umi b    11 UMi        1        1  Radial Velocity       2009
# 2   2    14 and b    14 And        1        1  Radial Velocity       2008
# 3   3    14 her b    14 Her        1        2  Radial Velocity       2002
# 4   4  16 cyg b b  16 Cyg B        3        1  Radial Velocity       1996
#
#                             disc_facility  pl_controv_flag   pl_orbper  ...  \
# 0                        Xinglong Station                0   326.03000  ...
# 1  Thueringer Landessternwarte Tautenburg                0   516.21997  ...
# 2       Okayama Astrophysical Observatory                0   185.84000  ...
# 3                  W. M. Keck Observatory                0  1773.40002  ...
# 4                  Multiple Observatories                0   798.50000  ...
#
# ...

# %%
a_planet_df=a_planet_df.sort_values('pl_name')
a_planet_df.tail(10)
# Out:
#         id   pl_name hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 4959  4959  xo-2 s c   XO-2 S        2        3  Radial Velocity       2014
# 4960  4960    xo-3 b     XO-3        1        1          Transit       2007
# 4961  4961    xo-4 b     XO-4        1        1          Transit       2008
# 4962  4962    xo-5 b     XO-5        1        1          Transit       2008
# 4963  4963    xo-6 b     XO-6        1        1          Transit       2016
# 4964  4964    xo-7 b     XO-7        1        1          Transit       2019
# 4965  4965  yses 2 b   YSES 2        1        1          Imaging       2021
# 4966  4966  yz cet b   YZ Cet        1        3  Radial Velocity       2017
# 4967  4967  yz cet c   YZ Cet        1        3  Radial Velocity       2017
# 4968  4968  yz cet d   YZ Cet        1        3  Radial Velocity       2017
#
#                            disc_facility  pl_controv_flag   pl_orbper  ...  \
# ...

# %%
final_planet_df.tail(10)
# Out:
#         id       name  light_years_from_earth     planet_mass  \
# 4999  4999   XO-2 S c                   494.0   1.37 Jupiters
# 5000  5000     XO-3 b                   695.0   7.29 Jupiters
# 5001  5001     XO-4 b                   889.0   1.42 Jupiters
# 5002  5002     XO-5 b                   901.0   1.19 Jupiters
# 5003  5003     XO-6 b                   768.0    4.4 Jupiters
# 5004  5004     XO-7 b                   764.0  0.709 Jupiters
# 5005  5005   YSES 2 b                   357.0    6.3 Jupiters
# 5006  5006  YZ Ceti b                    12.0      0.7 Earths
# 5007  5007  YZ Ceti c                    12.0     1.14 Earths
# 5008  5008  YZ Ceti d                    12.0     1.09 Earths
#
#       stellar_magnitude  discovery_date  \
# 4999             11.196            2014
# 5000              9.854            2007
# 5001             10.814            2008
# 5002             12.198            2008
# 5003             10.247            2016
# ...

# %%
merge_planet_df=pd.merge(final_planet_df,a_planet_df,on="id")
merge_planet_df.shape
# Out:
# (5009, 96)

# %%
merge_planet_df.columns
# Out:
# Index(['id', 'name', 'light_years_from_earth', 'planet_mass',
#        'stellar_magnitude', 'discovery_date', 'hyperlink', 'planet_type',
#        'planet_radius', 'orbital_radius', 'orbital_period', 'eccentricity',
#        'pl_name', 'hostname', 'sy_snum', 'sy_pnum', 'discoverymethod',
#        'disc_year', 'disc_facility', 'pl_controv_flag', 'pl_orbper',
#        'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax',
#        'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade',
#        'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1',
#        'pl_radjerr2', 'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1',
#        'pl_bmasseerr2', 'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1',
#        'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen',
#        'pl_orbeccenerr1', 'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol',
#        'pl_insolerr1', 'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1',
# ...

# %%
merge_planet_df.to_csv("merge_planets.csv")

# %%
from google.colab import files
files.download("merge_planets.csv")
